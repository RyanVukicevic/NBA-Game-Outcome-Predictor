# %% [markdown]
# NBA STATS API/LIBRARY
# https://github.com/swar/nba_api

# %% [markdown]
# static datasets for players, teams.
#
# https://github.com/swar/nba_api/blob/master/docs/nba_api/stats/examples.md#static-usage-examples

# %% [markdown]
# example for finding games
#
# https://github.com/swar/nba_api/blob/master/docs/examples/Finding%20Games.ipynb
